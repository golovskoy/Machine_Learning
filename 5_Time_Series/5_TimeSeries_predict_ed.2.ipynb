# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#EDA" data-toc-modified-id="EDA-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Выделение-нужных-столбцов-датафрейма" data-toc-modified-id="Выделение-нужных-столбцов-датафрейма-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Выделение нужных столбцов датафрейма</a></span></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Preprocessing</a></span></li><li><span><a href="#Удаление-дубликатов-и-выравнивание-временных-рядов" data-toc-modified-id="Удаление-дубликатов-и-выравнивание-временных-рядов-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Удаление дубликатов и выравнивание временных рядов</a></span></li><li><span><a href="#Заполнение-пропусков" data-toc-modified-id="Заполнение-пропусков-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Заполнение пропусков</a></span></li><li><span><a href="#Удаление-нерелевантных-данных," data-toc-modified-id="Удаление-нерелевантных-данных,-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Удаление нерелевантных данных,</a></span></li></ul></li><li><span><a href="#Моделирование-классических-моделей" data-toc-modified-id="Моделирование-классических-моделей-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Моделирование классических моделей</a></span><ul class="toc-item"><li><span><a href="#Генерация-дополнительных-признаков" data-toc-modified-id="Генерация-дополнительных-признаков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Генерация дополнительных признаков</a></span></li><li><span><a href="#Отделение-2х-недельной-выборки-для-тестирования" data-toc-modified-id="Отделение-2х-недельной-выборки-для-тестирования-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Отделение 2х недельной выборки для тестирования</a></span></li><li><span><a href="#Строим-baseline-прогноз-на-тренировочной-выборке,-отсекая-по-индексу" data-toc-modified-id="Строим-baseline-прогноз-на-тренировочной-выборке,-отсекая-по-индексу-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Строим baseline прогноз на тренировочной выборке, отсекая по индексу</a></span></li><li><span><a href="#Классические-МЛ-модели." data-toc-modified-id="Классические-МЛ-модели.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Классические МЛ модели.</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Градиентный-бустинг" data-toc-modified-id="Градиентный-бустинг-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Градиентный бустинг</a></span></li><li><span><a href="#Catboost" data-toc-modified-id="Catboost-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Catboost</a></span></li><li><span><a href="#Ridge" data-toc-modified-id="Ridge-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Ridge</a></span></li></ul></li><li><span><a href="#Модели-для-временных-рядов" data-toc-modified-id="Модели-для-временных-рядов-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Модели для временных рядов</a></span><ul class="toc-item"><li><span><a href="#Prophet" data-toc-modified-id="Prophet-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Prophet</a></span></li><li><span><a href="#Оценка-качества-модели" data-toc-modified-id="Оценка-качества-модели-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Оценка качества модели</a></span></li><li><span><a href="#Auto-arima-из-библиотеки-pmdarima." data-toc-modified-id="Auto-arima-из-библиотеки-pmdarima.-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Auto-arima из библиотеки pmdarima.</a></span></li><li><span><a href="#Оценка-качества-Auto-arima" data-toc-modified-id="Оценка-качества-Auto-arima-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Оценка качества Auto-arima</a></span></li><li><span><a href="#TBATS" data-toc-modified-id="TBATS-2.5.5"><span class="toc-item-num">2.5.5&nbsp;&nbsp;</span>TBATS</a></span></li><li><span><a href="#Оценка-качества-TBATS" data-toc-modified-id="Оценка-качества-TBATS-2.5.6"><span class="toc-item-num">2.5.6&nbsp;&nbsp;</span>Оценка качества TBATS</a></span></li><li><span><a href="#ETS-(Холт-Винтерс)" data-toc-modified-id="ETS-(Холт-Винтерс)-2.5.7"><span class="toc-item-num">2.5.7&nbsp;&nbsp;</span>ETS (Холт-Винтерс)</a></span></li><li><span><a href="#Оценка-качества-модели." data-toc-modified-id="Оценка-качества-модели.-2.5.8"><span class="toc-item-num">2.5.8&nbsp;&nbsp;</span>Оценка качества модели.</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Предсказание загруженности метро.

# %% [markdown]
# Цель - построить модель, которая предсказывает, сколько пассажиров будут им пользоваться в ближайшее время.

# %% [markdown]
# Информация о наборе данных:
#
# Почасовой объем трафика на межштатной автомагистрали 94 в западном направлении для станции MN DoT ATR 301, примерно на полпути между Миннеаполисом и Сент-Полом (Миннесота).

# %% [markdown]
# Информация о столбцах:
#
# Holiday - Категорический Национальные праздники США плюс региональный праздник штата Миннесота;
# Fair temp - Числовой Средняя температура в градусах Кельвина;
# rain_1h - Числовой Количество дождя в мм, выпавшего за час
# snow_1h - Числовой Количество снега в мм, выпавшего за час
# cloud_all - Числовой Процент облачного покрова
# Weather_main - Категориальный Краткое текстовое описание текущей погоды
# Weather_description Categorical - Более длинное текстовое описание текущей погоды
# date_time DateTime - Час данных, собранных по местному времени
# CST traffic_volume Numeric Hourly I-94 ATR 301 - сообщает об объеме трафика в западном направлении.

# %% [markdown]
# ## EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import plot_confusion_matrix

import tsfel

#from src.utils import *

from tsfresh.examples.har_dataset import download_har_dataset, load_har_dataset, load_har_classes
from tsfresh import extract_features, extract_relevant_features, select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh.feature_extraction import settings
from scipy.optimize import minimize
from scipy.stats import boxcox
from scipy.special import inv_boxcox

from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error, \
    median_absolute_error, mean_squared_error, mean_squared_log_error
from sklearn.model_selection import TimeSeriesSplit, cross_val_score

from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import GradientBoostingRegressor, RandomForestClassifier
from sklearn.linear_model import LassoCV, RidgeCV
from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from itertools import product
from tqdm import tqdm_notebook

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Выделение нужных столбцов датафрейма

# %%
df = pd.read_csv('D:\\Обучение\\OTUS\\Модуль 3\\Metro_Interstate_Traffic_Volume.csv')
df.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %% [markdown]
# Оставим только числовые столбцы датасета и время - traffic_volume (наша целевая переменная), date_time, holiday (является ли день некоторым праздником), temp (температура воздуха) и т.д.

# %%
df_cut = df[['traffic_volume', 'date_time', 'temp', 'clouds_all', 'rain_1h', 'snow_1h']]

# %% [markdown]
# ### Preprocessing

# %%
# #функция для вывода состава столбцов
def describe_cols(df_data):
    df = df_data
    values = pd.DataFrame()
    
    for col in df.columns:
        values[col] = [df[col].unique(), df[col].dtypes, df[col].nunique()]
        
    return values.transpose().sort_values(by=1, ascending=True).rename(
        {0: 'Значения', 1: 'тип данных', 2: 'Кол-во уникальных значений'}, axis=1)


# #функция для вывода пустых значений и их доли в столбцах датафрейма, 
# #а также явных дубликатов
def nan_values(df_data):
    df = df_data
    count_missing = df.isna().sum()
    percent_missing = round(df.isna().sum() * 100 / len(df), 2)
    count_duplicates = df.duplicated().sum()
    
    missing_value_df = pd.DataFrame({'column_name': df.columns,
                                     'num_missing': count_missing,
                                     'percent_missing': percent_missing,
                                     'num_duplicates': count_duplicates})
    
    return missing_value_df


# #функция для вывода информации о файле
def df_info (df_data):
    print('Количество строк файла:', df_data.shape[0])
    print('Количество столбцов файла:', df_data.shape[1])
    print()
    print('Информация о содержимом файла:')
    display(describe_cols(df_data))
    print()
    print('Информация о пропусках и явных дубликатах данных:')
    display(nan_values(df_data))
    print()
    print('Первые пять строк таблицы:')
    display(df_data.head())

# %%
df_info(df_cut)
# Out:
# Количество строк файла: 48204
# Количество столбцов файла: 6
#
# Информация о содержимом файла:
#                                                          Значения тип данных  \
# traffic_volume  [5545, 4516, 4767, 5026, 4918, 5181, 5584, 601...      int64
# clouds_all      [40, 75, 90, 1, 20, 0, 100, 92, 99, 81, 50, 72...      int64
# temp            [288.28, 289.36, 289.58, 290.13, 291.14, 291.7...    float64
# rain_1h         [0.0, 0.25, 0.57, 0.38, 0.3, 0.29, 0.44, 0.36,...    float64
# snow_1h         [0.0, 0.51, 0.32, 0.06, 0.05, 0.21, 0.25, 0.44...    float64
# date_time       [2012-10-02 09:00:00, 2012-10-02 10:00:00, 201...     object
#
#                Кол-во уникальных значений
# traffic_volume                       6704
# clouds_all                             60
# temp                                 5843
# rain_1h                               372
# snow_1h                                12
# date_time                           40575
# ...

# %% [markdown]
# Пропусков нет. Имеется 7551 дубликатов.

# %% [markdown]
# ### Удаление дубликатов и выравнивание временных рядов

# %%
df_cut= df_cut.drop_duplicates().reset_index(drop=True)
df_cut.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Визуализируем временной ряд.

# %%
df_cut[0:300].plot(x='date_time', y = 'traffic_volume', figsize=(16,4))
plt.xticks(rotation=45)
plt.yticks()

plt.show()

# %% [markdown]
# Заметна цикличность трафика. Ночью трафик стремиться к нулю и максимален с утра до 18 вечера. 06 и 13.10 минимумы по внутридневному трафику, соответствуют субботам. 14.10 тоже внутридневной трафик минимален это воскресенье.

# %% [markdown]
# Минимумы отстоят друг от друга на разном расстоянии, что говорит о пропусках часов.

# %%
#посмотрим на очередность часов
list = df_cut['date_time'].tolist()
list
# Out:
# ['2012-10-02 09:00:00',
#  '2012-10-02 10:00:00',
#  '2012-10-02 11:00:00',
#  '2012-10-02 12:00:00',
#  '2012-10-02 13:00:00',
#  '2012-10-02 14:00:00',
#  '2012-10-02 15:00:00',
#  '2012-10-02 16:00:00',
#  '2012-10-02 17:00:00',
#  '2012-10-02 18:00:00',
#  '2012-10-02 19:00:00',
#  '2012-10-02 20:00:00',
#  '2012-10-02 21:00:00',
#  '2012-10-02 22:00:00',
#  '2012-10-02 23:00:00',
#  '2012-10-03 00:00:00',
#  '2012-10-03 01:00:00',
#  '2012-10-03 02:00:00',
#  '2012-10-03 03:00:00',
#  '2012-10-03 04:00:00',
#  '2012-10-03 05:00:00',
#  '2012-10-03 06:00:00',
#  '2012-10-03 08:00:00',
#  '2012-10-03 09:00:00',
#  '2012-10-03 12:00:00',
#  '2012-10-03 13:00:00',
#  '2012-10-03 14:00:00',
#  '2012-10-03 15:00:00',
#  '2012-10-03 16:00:00',
#  '2012-10-03 18:00:00',
#  '2012-10-03 19:00:00',
#  '2012-10-03 20:00:00',
#  '2012-10-03 21:00:00',
#  '2012-10-03 22:00:00',
#  '2012-10-03 23:00:00',
#  '2012-10-04 00:00:00',
#  '2012-10-04 01:00:00',
#  '2012-10-04 02:00:00',
# ...

# %% [markdown]
# 3 ноября отсутствуют данные за 10 и 11 часов утра, 5 ноября отсутствуют утренние часы и т.д. Стартовое время 2012-10-02 09:00:00. Найдем конечное время.

# %%
df_cut['date_time'].max()
# Out:
# '2018-09-30 23:00:00'

# %% [markdown]
# Переведем столбец date_time из строк в тип datetime.

# %%
df_cut['date_time']=pd.to_datetime(df_cut['date_time'], format='%Y-%m-%d %H:%M:%S')
df_cut.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40654 entries, 0 to 40653
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   traffic_volume  40654 non-null  int64
#  1   date_time       40654 non-null  datetime64[ns]
#  2   temp            40654 non-null  float64
#  3   clouds_all      40654 non-null  int64
#  4   rain_1h         40654 non-null  float64
#  5   snow_1h         40654 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2)
# memory usage: 1.9 MB

# %%
#сгенерируем полный временной ряд
full_time = pd.date_range (start='2012-10-02 09:00:00', freq='H', end= '2018-09-30 23:00:00' )
full_time[0:30]
# Out:
# DatetimeIndex(['2012-10-02 09:00:00', '2012-10-02 10:00:00',
#                '2012-10-02 11:00:00', '2012-10-02 12:00:00',
#                '2012-10-02 13:00:00', '2012-10-02 14:00:00',
#                '2012-10-02 15:00:00', '2012-10-02 16:00:00',
#                '2012-10-02 17:00:00', '2012-10-02 18:00:00',
#                '2012-10-02 19:00:00', '2012-10-02 20:00:00',
#                '2012-10-02 21:00:00', '2012-10-02 22:00:00',
#                '2012-10-02 23:00:00', '2012-10-03 00:00:00',
#                '2012-10-03 01:00:00', '2012-10-03 02:00:00',
#                '2012-10-03 03:00:00', '2012-10-03 04:00:00',
#                '2012-10-03 05:00:00', '2012-10-03 06:00:00',
#                '2012-10-03 07:00:00', '2012-10-03 08:00:00',
#                '2012-10-03 09:00:00', '2012-10-03 10:00:00',
#                '2012-10-03 11:00:00', '2012-10-03 12:00:00',
#                '2012-10-03 13:00:00', '2012-10-03 14:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
#переведем датафрейм для возможности объединения 
frame_time=full_time.to_frame()
frame_time.set_axis(['date_time'], axis='columns', inplace=True)
frame_time.reset_index(drop=True)
# Out:
#                 date_time
# 0     2012-10-02 09:00:00
# 1     2012-10-02 10:00:00
# 2     2012-10-02 11:00:00
# 3     2012-10-02 12:00:00
# 4     2012-10-02 13:00:00
# ...                   ...
# 52546 2018-09-30 19:00:00
# 52547 2018-09-30 20:00:00
# 52548 2018-09-30 21:00:00
# 52549 2018-09-30 22:00:00
# 52550 2018-09-30 23:00:00
#
# [52551 rows x 1 columns]

# %%
#объединим полный временной ряд с датафреймом, устранив пробелы таким образом
join_df=frame_time.join(df_cut.set_index('date_time'), on='date_time',how='left').reset_index(drop=True)
join_df[20:30]
# Out:
#              date_time  traffic_volume    temp  clouds_all  rain_1h  snow_1h
# 20 2012-10-03 05:00:00          2718.0  278.62         1.0      0.0      0.0
# 21 2012-10-03 06:00:00          5673.0  278.23         1.0      0.0      0.0
# 22 2012-10-03 07:00:00             NaN     NaN         NaN      NaN      NaN
# 23 2012-10-03 08:00:00          6511.0  278.12         1.0      0.0      0.0
# 24 2012-10-03 09:00:00          5471.0  282.48         1.0      0.0      0.0
# 25 2012-10-03 10:00:00             NaN     NaN         NaN      NaN      NaN
# 26 2012-10-03 11:00:00             NaN     NaN         NaN      NaN      NaN
# 27 2012-10-03 12:00:00          5097.0  291.97         1.0      0.0      0.0
# 28 2012-10-03 13:00:00          4887.0  293.23         1.0      0.0      0.0
# 29 2012-10-03 14:00:00          5337.0  294.31         1.0      0.0      0.0

# %% [markdown]
# ### Заполнение пропусков

# %%
join_df['traffic_volume'] = join_df['traffic_volume'].interpolate()
join_df['clouds_all'] = join_df['clouds_all'].interpolate()
join_df['rain_1h'] = join_df['rain_1h'].interpolate()
join_df['snow_1h'] = join_df['snow_1h'].interpolate()
join_df['temp'] = join_df['temp'].interpolate()
join_df[20:30]
# Out:
#              date_time  traffic_volume        temp  clouds_all  rain_1h  \
# 20 2012-10-03 05:00:00     2718.000000  278.620000         1.0      0.0
# 21 2012-10-03 06:00:00     5673.000000  278.230000         1.0      0.0
# 22 2012-10-03 07:00:00     6092.000000  278.175000         1.0      0.0
# 23 2012-10-03 08:00:00     6511.000000  278.120000         1.0      0.0
# 24 2012-10-03 09:00:00     5471.000000  282.480000         1.0      0.0
# 25 2012-10-03 10:00:00     5346.333333  285.643333         1.0      0.0
# 26 2012-10-03 11:00:00     5221.666667  288.806667         1.0      0.0
# 27 2012-10-03 12:00:00     5097.000000  291.970000         1.0      0.0
# 28 2012-10-03 13:00:00     4887.000000  293.230000         1.0      0.0
# 29 2012-10-03 14:00:00     5337.000000  294.310000         1.0      0.0
#
#     snow_1h
# 20      0.0
# 21      0.0
# 22      0.0
# 23      0.0
# 24      0.0
# 25      0.0
# 26      0.0
# 27      0.0
# 28      0.0
# 29      0.0

# %% [markdown]
# ### Удаление нерелевантных данных,

# %%
join_df.plot(x='date_time', y = 'traffic_volume', figsize=(16,4))
plt.xticks(rotation=45)
plt.yticks()
plt.show()

# %% [markdown]
# В конце 2014 наблюдается разрыв в данных.

# %%
#посмотрим на разрыв ближе
int = join_df.query('date_time > "2014-01-03 00:00:00" and date_time < "2015-10-03 00:00:00"')
int.plot(x='date_time', y = 'traffic_volume', figsize=(16,4))
plt.xticks(rotation=45)
plt.yticks()
plt.show()

# %% [markdown]
# Разрыв имеет длительность немного меньше года. Оставим данные в датафрейме, начинающиеся с июля 2015 г.

# %%
#переименуем датафрейм
good_df=join_df.query('date_time > "2015-07-01 00:00:00"')
good_df[0:300].plot(x='date_time', y = 'traffic_volume', figsize=(16,4))
plt.xticks(rotation=45)
plt.yticks()
plt.show()

# %% [markdown]
# 3 дня выходных 03-05 вероятно приурочены к Дню Независимости в США.

# %% [markdown]
# ## Моделирование классических моделей

# %% [markdown]
# ###  Генерация дополнительных признаков

# %%
class_df = good_df.copy()
class_df["hour"] = pd.DatetimeIndex(class_df['date_time']).hour
class_df["day"] = pd.DatetimeIndex(class_df['date_time']).day
class_df["weekday"] = pd.DatetimeIndex(class_df['date_time']).weekday
class_df["month"] = pd.DatetimeIndex(class_df['date_time']).month
class_df["year"] = pd.DatetimeIndex(class_df['date_time']).year
#удалим столбец с датой
class_df=class_df.drop(['date_time'], axis=1).reset_index(drop=True)
class_df.sample(10, random_state=42)
class_df.head()
# Out:
#    traffic_volume    temp  clouds_all  rain_1h  snow_1h  hour  day  weekday  \
# 0           444.0  289.40         1.0      0.0      0.0     1    1        2
# 1           347.0  289.19         1.0      0.0      0.0     2    1        2
# 2           356.0  288.74         1.0      0.3      0.0     3    1        2
# 3           936.0  288.07         1.0      0.0      0.0     4    1        2
# 4          2886.0  287.87         1.0      0.0      0.0     5    1        2
#
#    month  year
# 0      7  2015
# 1      7  2015
# 2      7  2015
# 3      7  2015
# 4      7  2015

# %%
#сгенерируем дополнительные признаки с помощью PolynomialFeatures
from sklearn.preprocessing import PolynomialFeatures
#установим степень 2 и получим попарные произведения и квадраты всех признаков
poly = PolynomialFeatures(degree=2)
features = poly.fit_transform(class_df)
#выведем 2 первые строки новых признаков
features[:2]
# Out:
# array([[1.00000000e+00, 4.44000000e+02, 2.89400000e+02, 1.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         2.00000000e+00, 7.00000000e+00, 2.01500000e+03, 1.97136000e+05,
#         1.28493600e+05, 4.44000000e+02, 0.00000000e+00, 0.00000000e+00,
#         4.44000000e+02, 4.44000000e+02, 8.88000000e+02, 3.10800000e+03,
#         8.94660000e+05, 8.37523600e+04, 2.89400000e+02, 0.00000000e+00,
#         0.00000000e+00, 2.89400000e+02, 2.89400000e+02, 5.78800000e+02,
#         2.02580000e+03, 5.83141000e+05, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 2.00000000e+00,
#         7.00000000e+00, 2.01500000e+03, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
# ...

# %% [markdown]
# ### Отделение 2х недельной выборки для тестирования

# %%
#определим относительный размер тестовой выборки, равной 2м неделям
size = 14*24/len(class_df)
size
# Out:
# 0.011762234824616677

# %%
#Разделим на трейн и тест по индексу, чтобы данные шли последовательно
y = class_df["traffic_volume"]
X = class_df.drop(["traffic_volume"], axis=1)
test_index = round(len(class_df)*(1-size))
X_train = X.iloc[:test_index]
y_train = y.iloc[:test_index]
X_test = X.iloc[test_index:]
y_test = y.iloc[test_index:]

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((28230, 9), (336, 9), (28230,), (336,))

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28230 entries, 0 to 28229
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   temp        28230 non-null  float64
#  1   clouds_all  28230 non-null  float64
#  2   rain_1h     28230 non-null  float64
#  3   snow_1h     28230 non-null  float64
#  4   hour        28230 non-null  int64
#  5   day         28230 non-null  int64
#  6   weekday     28230 non-null  int64
#  7   month       28230 non-null  int64
#  8   year        28230 non-null  int64
# dtypes: float64(4), int64(5)
# memory usage: 1.9 MB

# %% [markdown]
# ### Строим baseline прогноз на тренировочной выборке, отсекая по индексу

# %%
#Средние значения по дням недели на каждый час дня
baseline = round(class_df.iloc[:test_index].groupby(["weekday", "hour"])["traffic_volume"].mean())
print(baseline[20:30])
len(baseline)
# Out:
# weekday  hour
# 0        20      2575.0
#          21      2271.0
#          22      1744.0
#          23      1140.0
# 1        0        650.0
#          1        418.0
#          2        333.0
#          3        420.0
#          4        938.0
#          5       2898.0
# Name: traffic_volume, dtype: float64
# 168

# %% [markdown]
# Длина соответсвует 24*7 значит все верно.

# %%
baseline.plot(figsize=(16,4))
plt.xlabel('weekday')
plt.show()

# %% [markdown]
# 5,6 - суббота и воскресенье имеют меньший трафик. Среда, четверг и пятница имеют больший трафик, чем в остальные дни.

# %%
#создадим вектор длинной 336 из значений baseline-модели
predict = pd.concat([baseline, baseline])
#создадим датафрейм
predict=pd.DataFrame(data=predict, columns = ['traffic_volume']).reset_index()
predict
# Out:
#      weekday  hour  traffic_volume
# 0          0     0           675.0
# 1          0     1           434.0
# 2          0     2           338.0
# 3          0     3           404.0
# 4          0     4           900.0
# ..       ...   ...             ...
# 331        6    19          3192.0
# 332        6    20          2821.0
# 333        6    21          2383.0
# 334        6    22          1841.0
# 335        6    23          1248.0
#
# [336 rows x 3 columns]

# %%
test = pd.DataFrame(data=y_test, columns = ['traffic_volume'])
print(test)
# Out:
#        traffic_volume
# 28230           550.0
# 28231           280.0
# 28232           260.0
# 28233           344.0
# 28234           880.0
# ...               ...
# 28561          3543.0
# 28562          2781.0
# 28563          2159.0
# 28564          1450.0
# 28565           954.0
#
# [336 rows x 1 columns]

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

error=mean_absolute_percentage_error(test['traffic_volume'], predict['traffic_volume'])
print("Mean absolute percentage error {0:.2f}%".format(error))
# Out:
# Mean absolute percentage error nan%

# %%
from math import sqrt
rmse = sqrt(mean_squared_error(test['traffic_volume'], predict['traffic_volume']))
print("Root mean squared error:", round(rmse))
# Out:
# Root mean squared error: 303

# %% [markdown]
# Для нашего уровня значений ошибка большая.

# %% [markdown]
# ### Классические МЛ модели.

# %% [markdown]
# #### Линейная регрессия

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Зададим 2 функции:
# 1. Функция для подсчета MAPE.
# 2. Функция для отображения прогнозных значений, доверительного интервала (95%) и аномалий.

# %%
def plotModelResults(model, X_train, y_train, X_test, y_test,
                     plot_train=False, plot_intervals=False, plot_anomalies=False):
    """
    Plots modelled vs fact values, prediction intervals and anomalies
    """
    tscv = TimeSeriesSplit(n_splits=5)
    prediction = model.predict(X_test)
    
    N_train = len(y_train)
    N_test = len(y_test)
    train_index = range(N_train)
    test_index = range(N_train, N_train+N_test)
    
    plt.figure(figsize=(15, 7))
    if plot_train:
        plt.plot(train_index, y_train.values, label="train actual")
    plt.plot(test_index, y_test.values, label="actual", linewidth=2.0)
    plt.plot(test_index, prediction, "g", label="prediction", linewidth=2.0)
    
    if plot_intervals:
        cv = cross_val_score(model, X_train, y_train, cv=tscv, scoring="neg_mean_absolute_error")
        mae = cv.mean() * (-1)
        deviation = cv.std()
        
        scale = 1.96
        lower = prediction - (mae + scale * deviation)
        upper = prediction + (mae + scale * deviation)
        
        plt.plot(test_index, lower, "r--", label="upper bond / lower bond", alpha=0.5)
        plt.plot(test_index, upper, "r--", alpha=0.5)
        
        if plot_anomalies:
            anomalies = np.array([np.NaN]*len(y_test))
            anomalies[y_test<lower] = y_test[y_test<lower]
            anomalies[y_test>upper] = y_test[y_test>upper]
            plt.plot(test_index, anomalies, "o", markersize=10, label = "Anomalies")
    
    error = mean_absolute_percentage_error(prediction, y_test)
    plt.title("Mean absolute percentage error {0:.2f}%".format(error))
    plt.legend(loc="best")
    plt.tight_layout()
    plt.grid(True)

# %%
plotModelResults(lr, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, plot_intervals=True)

# %% [markdown]
# Ошибка огромна и составляет порядка 50%.

# %% [markdown]
# #### Градиентный бустинг

# %%
gb = GradientBoostingRegressor(n_estimators=100)
gb.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
plotModelResults(gb, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, plot_intervals=True)

# %% [markdown]
# У градиентного бустинга ошибка меньше и составляет 17%.

# %% [markdown]
# Увеличим количество деревьев.

# %%
gb = GradientBoostingRegressor(n_estimators=200)
gb.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(n_estimators=200)

# %%
plotModelResults(gb, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, plot_intervals=True)

# %% [markdown]
# При увеличении количества деревье ошибку удалось снизить до 13%.

# %% [markdown]
# #### Catboost

# %%
from catboost import CatBoostRegressor 

cb = CatBoostRegressor(logging_level='Silent')
cb.fit(X_train, y_train)

# %%
plotModelResults(cb, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, plot_intervals=True)

# %% [markdown]
# ошибка получилась 10%.

# %% [markdown]
# #### Ridge

# %%
# Ridge регрессия
ridge = Ridge()
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
plotModelResults(ridge, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test, plot_intervals=True)

# %% [markdown]
# Похоже на линейную регрессию и дает ошибку 50%.

# %% [markdown]
# ### Модели для временных рядов

# %% [markdown]
# #### Prophet

# %%
# Установка fbprophet
# step 1: conda install -c anaconda ephem
# step 2:conda install -c conda-forge pystan
# step 3: conda install -c conda-forge fbprophet
# step 3: pip install fbprophet

# %% [markdown]
# Ссылки для себя.
# https://habr.com/ru/company/ods/blog/323730/
# https://biconsult.ru/products/model-facebook-prophet-s-ispolzovaniem-python

# %%
#импортируем библиотеку
from fbprophet import Prophet

# %% [markdown]
# В отличии от классических моделей в X будем передавать сам временной ряд в формате datetime и температуру.

# %%
#здесь у нас будут столбцы с полной датой и температурой
#приведем к формату читаемому библиотекой
fb_pr = good_df[['traffic_volume', 'date_time', 'temp']].reset_index(drop=True)
fb_pr.rename(columns={'traffic_volume': 'y', 'date_time': 'ds'}, inplace=True)
#Разделяем трейн и тест по индексу, который использовали для классических моделей
train_df = fb_pr.iloc[:test_index]
test_df = fb_pr.iloc[test_index:]
print(train_df.head())
train_df.shape, test_df.shape
# Out:
#         y                  ds    temp
# 0   444.0 2015-07-01 01:00:00  289.40
# 1   347.0 2015-07-01 02:00:00  289.19
# 2   356.0 2015-07-01 03:00:00  288.74
# 3   936.0 2015-07-01 04:00:00  288.07
# 4  2886.0 2015-07-01 05:00:00  287.87
# ((28230, 3), (336, 3))

# %%
#Инициализируем и обучаем модель 
m = Prophet()
m.fit(train_df)
# С помощью вспомогательной функции Prophet.make_future_dataframe создаем dataframe, 
# который содержит все исторические временные точки и еще 2 недели прогноза
future = m.make_future_dataframe(periods=336)
forecast = m.predict(future)

# %%
#future['temp'] = good_df['temp']
#Для того, чтобы построить прогноз вызываем у модели функцию predict и передаем 
#в нее полученный на предыдущем шаге dataframe 
forecast = m.predict(future)

# %%
#визуализируем предсказания
m.plot(forecast)

# %%
m.plot_components(forecast)

# %% [markdown]
# По трафику имеются тренды в различные периоды, как восходящие, так и нисходящие. Со вторника по пятницу мы видим увеличенный трафик. Годовая сезонность указывает на провал трафика в новогодние праздники. Дневная сезонность показывает, что после 17:00 трафик постепенно снижается и достигает минимума в 2-4 часа ночи.

# %% [markdown]
# #### Оценка качества модели

# %%
# Посмотрим на датасет с предсказаниями
forecast.head()
# Out:
#                    ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0 2015-07-01 01:00:00  3320.065508  -506.938384  1777.151487  3320.065508
# 1 2015-07-01 02:00:00  3320.081356  -873.110292  1376.628415  3320.081356
# 2 2015-07-01 03:00:00  3320.097204  -734.601277  1474.731960  3320.097204
# 3 2015-07-01 04:00:00  3320.113052   203.581783  2384.971855  3320.113052
# 4 2015-07-01 05:00:00  3320.128901  1521.312960  3646.375947  3320.128901
#
#    trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0  3320.065508    -2668.491178          -2668.491178          -2668.491178
# 1  3320.081356    -3088.806928          -3088.806928          -3088.806928
# 2  3320.097204    -2905.818642          -2905.818642          -2905.818642
# 3  3320.113052    -2013.777212          -2013.777212          -2013.777212
# 4  3320.128901     -686.304926           -686.304926           -686.304926
#
# ...

# %%
error=mean_absolute_percentage_error(test_df['y'], forecast['yhat'])
print("Mean absolute percentage error {0:.2f}%".format(error))
# Out:
# Mean absolute percentage error 113.88%

# %%
test_df['y']
# Out:
# 28230     550.0
# 28231     280.0
# 28232     260.0
# 28233     344.0
# 28234     880.0
#           ...
# 28561    3543.0
# 28562    2781.0
# 28563    2159.0
# 28564    1450.0
# 28565     954.0
# Name: y, Length: 336, dtype: float64

# %% [markdown]
# Возьмем RMSE.

# %%
#библиотеки импортируем
from sklearn.metrics import mean_squared_error

#рассчитаем RMSE
test_y = test_df['y']
forecast_yh = forecast['yhat']
rmse = sqrt(mean_squared_error(test_y, forecast_yh[:336]))
print("Root mean squared error:", round(rmse))
# Out:
# Root mean squared error: 1185

# %% [markdown]
# Ошибки очень большие.

# %% [markdown]
# #### Auto-arima из библиотеки pmdarima.

# %% [markdown]
# Модель Sarima не считалась, т.к. не хватало памяти, поэтому взял Auto-arima.

# %%
#подготовим датасет для моделей временных рядов
y=train_df[['ds', 'y']].set_index('ds')#=train_df.drop('temp')
y
# Out:
#                           y
# ds
# 2015-07-01 01:00:00   444.0
# 2015-07-01 02:00:00   347.0
# 2015-07-01 03:00:00   356.0
# 2015-07-01 04:00:00   936.0
# 2015-07-01 05:00:00  2886.0
# ...                     ...
# 2018-09-16 19:00:00  3400.0
# 2018-09-16 20:00:00  3092.0
# 2018-09-16 21:00:00  2623.0
# 2018-09-16 22:00:00  1725.0
# 2018-09-16 23:00:00  1088.0
#
# [28230 rows x 1 columns]

# %%
import pmdarima as pm
import matplotlib.pyplot as plt

# Обучтм модель
model = pm.auto_arima(y, seasonal=True)

# Сделаем предсказания для 336 часов вперед
forecasts = model.predict(336) 

# Визуализируем (blue=тренировочная часть, green=предсказания)
x = np.arange(y.shape[0])
plt.plot(x[:28230], y, c='blue')
plt.plot(x[:336], forecasts, c='green')
plt.show()

# %%
#установим удобный размер для визуализации
plt.plot(x[:336], y[:336], c='blue')
plt.plot(x[:336], forecasts, c='green')
plt.show()

# %% [markdown]
# Визуально видно, что ряд плохо предсказывается.

# %% [markdown]
# #### Оценка качества Auto-arima

# %%
error=mean_absolute_percentage_error(test_df['y'], forecasts)
print("Mean absolute percentage error {0:.2f}%".format(error))
# Out:
# Mean absolute percentage error 166.42%

# %%
rmse = sqrt(mean_squared_error(test_y, forecasts))
print("Root mean squared error:", round(rmse))
# Out:
# Root mean squared error: 1921

# %% [markdown]
# Ошибки очень большие, как и при визуализации.

# %% [markdown]
# #### TBATS

# %%
from tbats import BATS, TBATS

# %%
# Запустим модель без преобразования Бокса-Кокса и моделирования ошибок ARMA, 
#которые являются самыми медленными элементами модели
estimator = TBATS(seasonal_periods=[168, 732], #установил недельные и месячные сезонности
    use_arma_errors=False, # будем пробовать только модели без ARMA 
    use_box_cox=False # не буду использовать Box-Cox 
) 
fit_model = estimator.fit(y)

# %%
y_forecast = fit_model.forecast(steps=336)

# %%
# Визуализируем (blue=тренировочная часть, green=предсказания)
plt.plot(x[:336], y[:336], c='blue')
plt.plot(x[:336], y_forecast, c='green')
plt.show()

# %% [markdown]
# Визуально предсказывает лучше, но выходные дни плохо получается.

# %% [markdown]
# #### Оценка качества TBATS

# %%
error=mean_absolute_percentage_error(test_df['y'], y_forecast)
print("Mean absolute percentage error {0:.2f}%".format(error))

# %%
rmse = sqrt(mean_squared_error(test_y, y_forecast))
print("Root mean squared error:", round(rmse))

# %% [markdown]
# Ошибка большая получилась.

# %% [markdown]
# #### ETS (Холт-Винтерс)

# %%
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
#найдем количество недельных периодов
n_per = round(len(y['y'])/168)
n_per

# %%
#обучим модель
fit1 = ExponentialSmoothing(np.asarray(y['y']), seasonal_periods=n_per,
                            trend='add', seasonal='add').fit()
#создадим столбец с предсказаниями
test_df['Holt_Winter'] = fit1.forecast(len(test_df))

# %% [markdown]
# #### Оценка качества модели.

# %%
error=mean_absolute_percentage_error(test_df['y'], test_df['Holt_Winter'])
print("Mean absolute percentage error {0:.2f}%".format(error))

# %%
rmse = sqrt(mean_squared_error(test_y, test_df['Holt_Winter']))
print("Root mean squared error:", round(rmse))

# %% [markdown]
# Ошибки большие.

# %%
test_df['Holt_Winter']

# %%
plt.figure(figsize=(16,8))
#plt.plot(y['y'], label='Train')
plt.plot(test_df['y'], label='Test')
plt.plot(test_df['Holt_Winter'], label='Holt_Winter')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Точно предсказать у меня не получилось.
